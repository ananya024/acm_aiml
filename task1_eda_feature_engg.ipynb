# %%
import pandas as pd
df = pd.read_excel('FPL_allplayers_last3_gwk_6.xlsx')
df
# Out:
#               Player Team  Pos  GW  Minutes  Goals  Assists  BPS  Points  \
# 0       Aaron Hickey  BRE  DEF   4        7      0        0   -1       1
# 1       Aaron Hickey  BRE  DEF   5        0      0        0    0       0
# 2       Aaron Hickey  BRE  DEF   6       74      0        0    9       2
# 3     Aaron Ramsdale  NEW   GK   4        0      0        0    0       0
# 4     Aaron Ramsdale  NEW   GK   5        0      0        0    0       0
# ...              ...  ...  ...  ..      ...    ...      ...  ...     ...
# 2217  Đorđe Petrović  BOU   GK   5       90      0        0   22       6
# 2218  Đorđe Petrović  BOU   GK   6       90      0        0   18       3
# 2219  İlkay Gündoğan  MCI  MID   4        0      0        0    0       0
# 2220  İlkay Gündoğan  MCI  MID   5        0      0        0    0       0
# 2221  İlkay Gündoğan  MCI  MID   6        0      0        0    0       0
#
#       expected_goals  expected_assists  expected_goal_involvements
# 0                0.0              0.00                        0.00
# 1                0.0              0.00                        0.00
# 2                0.0              0.03                        0.03
# 3                0.0              0.00                        0.00
# 4                0.0              0.00                        0.00
# ...              ...               ...                         ...
# 2217             0.0              0.00                        0.00
# 2218             0.0              0.00                        0.00
# 2219             0.0              0.00                        0.00
# 2220             0.0              0.00                        0.00
# 2221             0.0              0.00                        0.00
#
# [2222 rows x 12 columns]

# %%
df.info()
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2222 entries, 0 to 2221
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Player                      2222 non-null   object
#  1   Team                        2222 non-null   object
#  2   Pos                         2222 non-null   object
#  3   GW                          2222 non-null   int64
#  4   Minutes                     2222 non-null   int64
#  5   Goals                       2222 non-null   int64
#  6   Assists                     2222 non-null   int64
#  7   BPS                         2222 non-null   int64
#  8   Points                      2222 non-null   int64
#  9   expected_goals              2222 non-null   float64
#  10  expected_assists            2222 non-null   float64
#  11  expected_goal_involvements  2222 non-null   float64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 208.4+ KB
#                 GW      Minutes        Goals      Assists          BPS  \
# count  2222.000000  2222.000000  2222.000000  2222.000000  2222.000000
# mean      5.000450    26.521602     0.033303     0.032403     4.596310
# std       0.816588    37.552787     0.191602     0.184578     8.952848
# min       4.000000     0.000000     0.000000     0.000000   -23.000000
# 25%       4.000000     0.000000     0.000000     0.000000     0.000000
# 50%       5.000000     0.000000     0.000000     0.000000     0.000000
# 75%       6.000000    67.000000     0.000000     0.000000     6.000000
# max       6.000000    90.000000     2.000000     2.000000    68.000000
#
#             Points  expected_goals  expected_assists  \
# count  2222.000000     2222.000000       2222.000000
# mean      1.186319        0.032975          0.021760
# std       2.313057        0.118924          0.065368
# min      -3.000000        0.000000          0.000000
# 25%       0.000000        0.000000          0.000000
# 50%       0.000000        0.000000          0.000000
# 75%       1.000000        0.000000          0.010000
# max      17.000000        1.800000          0.750000
#
#        expected_goal_involvements
# count                 2222.000000
# mean                     0.054725
# std                      0.145503
# min                      0.000000
# 25%                      0.000000
# 50%                      0.000000
# 75%                      0.020000
# max                      1.810000

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
df = pd.get_dummies(df.iloc[:, 1:])
df
# Out:
#       GW  Minutes  Goals  Assists  BPS  Points  expected_goals  \
# 0      4        7      0        0   -1       1             0.0
# 1      5        0      0        0    0       0             0.0
# 2      6       74      0        0    9       2             0.0
# 3      4        0      0        0    0       0             0.0
# 4      5        0      0        0    0       0             0.0
# ...   ..      ...    ...      ...  ...     ...             ...
# 2217   5       90      0        0   22       6             0.0
# 2218   6       90      0        0   18       3             0.0
# 2219   4        0      0        0    0       0             0.0
# 2220   5        0      0        0    0       0             0.0
# 2221   6        0      0        0    0       0             0.0
#
#       expected_assists  expected_goal_involvements  Team_ARS  ...  Team_NEW  \
# 0                 0.00                        0.00     False  ...     False
# 1                 0.00                        0.00     False  ...     False
# 2                 0.03                        0.03     False  ...     False
# 3                 0.00                        0.00     False  ...      True
# 4                 0.00                        0.00     False  ...      True
# ...                ...                         ...       ...  ...       ...
# 2217              0.00                        0.00     False  ...     False
# 2218              0.00                        0.00     False  ...     False
# 2219              0.00                        0.00     False  ...     False
# 2220              0.00                        0.00     False  ...     False
# 2221              0.00                        0.00     False  ...     False
#
#       Team_NFO  Team_SUN  Team_TOT  Team_WHU  Team_WOL  Pos_DEF  Pos_FWD  \
# 0        False     False     False     False     False     True    False
# 1        False     False     False     False     False     True    False
# 2        False     False     False     False     False     True    False
# 3        False     False     False     False     False    False    False
# 4        False     False     False     False     False    False    False
# ...        ...       ...       ...       ...       ...      ...      ...
# 2217     False     False     False     False     False    False    False
# 2218     False     False     False     False     False    False    False
# 2219     False     False     False     False     False    False    False
# 2220     False     False     False     False     False    False    False
# 2221     False     False     False     False     False    False    False
#
#       Pos_GK  Pos_MID
# 0      False    False
# 1      False    False
# 2      False    False
# 3       True    False
# 4       True    False
# ...      ...      ...
# 2217    True    False
# 2218    True    False
# 2219   False     True
# 2220   False     True
# 2221   False     True
#
# [2222 rows x 33 columns]

# %%
num_df = df.select_dtypes(include=['float64', 'int64'])
num_df
# Out:
#       GW  Minutes  Goals  Assists  BPS  Points  expected_goals  \
# 0      4        7      0        0   -1       1             0.0
# 1      5        0      0        0    0       0             0.0
# 2      6       74      0        0    9       2             0.0
# 3      4        0      0        0    0       0             0.0
# 4      5        0      0        0    0       0             0.0
# ...   ..      ...    ...      ...  ...     ...             ...
# 2217   5       90      0        0   22       6             0.0
# 2218   6       90      0        0   18       3             0.0
# 2219   4        0      0        0    0       0             0.0
# 2220   5        0      0        0    0       0             0.0
# 2221   6        0      0        0    0       0             0.0
#
#       expected_assists  expected_goal_involvements
# 0                 0.00                        0.00
# 1                 0.00                        0.00
# 2                 0.03                        0.03
# 3                 0.00                        0.00
# 4                 0.00                        0.00
# ...                ...                         ...
# 2217              0.00                        0.00
# 2218              0.00                        0.00
# 2219              0.00                        0.00
# 2220              0.00                        0.00
# 2221              0.00                        0.00
#
# [2222 rows x 9 columns]

# %%
corr_mat = num_df.corr()
print("Correlation Matrix:")
display(corr_mat)
# Out:
# Correlation Matrix:
#                                   GW   Minutes     Goals   Assists       BPS  \
# GW                          1.000000 -0.000287  0.037315  0.038737 -0.023563
# Minutes                    -0.000287  1.000000  0.214099  0.237319  0.702710
# Goals                       0.037315  0.214099  1.000000  0.109517  0.590015
# Assists                     0.038737  0.237319  0.109517  1.000000  0.403267
# BPS                        -0.023563  0.702710  0.590015  0.403267  1.000000
# Points                     -0.034371  0.685176  0.640255  0.434056  0.941006
# expected_goals              0.028175  0.356915  0.597334  0.134061  0.453202
# expected_assists            0.006649  0.436101  0.081236  0.409115  0.432671
# expected_goal_involvements  0.025978  0.487546  0.524727  0.293381  0.564791
#
#                               Points  expected_goals  expected_assists  \
# GW                         -0.034371        0.028175          0.006649
# Minutes                     0.685176        0.356915          0.436101
# Goals                       0.640255        0.597334          0.081236
# Assists                     0.434056        0.134061          0.409115
# BPS                         0.941006        0.453202          0.432671
# Points                      1.000000        0.491069          0.368568
# expected_goals              0.491069        1.000000          0.177215
# expected_assists            0.368568        0.177215          1.000000
# expected_goal_involvements  0.566940        0.896938          0.594103
#
#                             expected_goal_involvements
# GW                                            0.025978
# Minutes                                       0.487546
# Goals                                         0.524727
# Assists                                       0.293381
# BPS                                           0.564791
# Points                                        0.566940
# expected_goals                                0.896938
# expected_assists                              0.594103
# expected_goal_involvements                    1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 12))
sns.heatmap(corr_mat, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()
